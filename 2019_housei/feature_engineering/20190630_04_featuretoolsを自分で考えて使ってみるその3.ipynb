# %% [markdown]
# # README
# - 素で書いてみることにより、featuretoolsのありがたみを知る

# %% [markdown]
# # expectedの作成

# %%
import featuretools
import pandas as pd
import copy


data = featuretools.demo.load_mock_customer()

# %%
# いちいちKey打つのだるい&型がわかりにくいので変数化
df_customers = data['customers']
df_sessions = data['sessions']
df_transactions = data['transactions']

# %%
entity_set = featuretools.EntitySet(id='data')

entity_set.entity_from_dataframe(entity_id='customer',
                                 dataframe=df_customers,
                                 index='customer_id')

entity_set.entity_from_dataframe(entity_id='session',
                                 dataframe=df_sessions,
                                 index='session_id')

entity_set.entity_from_dataframe(entity_id='transaction',
                                 dataframe=df_transactions,
                                 index='transaction_id')

entity_set
# Out:
# Entityset: data
#   Entities:
#     customer [Rows: 5, Columns: 4]
#     session [Rows: 35, Columns: 4]
#     transaction [Rows: 500, Columns: 5]
#   Relationships:
#     No relationships

# %%
relation_customer_and_session = featuretools.Relationship(
    parent_variable=entity_set['customer']['customer_id'],
    child_variable=entity_set['session']['customer_id'])

relation_session_and_transaction = featuretools.Relationship(
    parent_variable=entity_set['session']['session_id'],
    child_variable=entity_set['transaction']['session_id'])

entity_set.add_relationships(relationships=[relation_customer_and_session,
                                            relation_session_and_transaction])
# Out:
# Entityset: data
#   Entities:
#     customer [Rows: 5, Columns: 4]
#     session [Rows: 35, Columns: 4]
#     transaction [Rows: 500, Columns: 5]
#   Relationships:
#     session.customer_id -> customer.customer_id
#     transaction.session_id -> session.session_id

# %%
agg_numeric = ['sum', 'max',
               'count', 'mode'
               ]
agg_trans = ['year', 'month']  # いろいろ変えてみるといいよ

expected, feature_defs = featuretools.dfs(entityset=entity_set,
                                          target_entity='session',
                                          agg_primitives=agg_numeric,
                                          trans_primitives=agg_trans,
                                          max_depth=1)

# %%
expected.head(3).T
# Out:
# session_id                          1       2       3
# customer_id                         2       5       4
# device                        desktop  mobile  mobile
# SUM(transaction.amount)       1229.01  746.96    1329
# MAX(transaction.amount)        141.66  135.25  147.73
# COUNT(transaction)                 16      10      15
# MODE(transaction.product_id)        3       5       1
# YEAR(session_start)              2014    2014    2014
# MONTH(session_start)                1       1       1
# customer.zip_code               13244   60091   60091

# %%
expected.head(3)
# Out:
#             customer_id   device  SUM(transaction.amount)  \
# session_id
# 1                     2  desktop                  1229.01
# 2                     5   mobile                   746.96
# 3                     4   mobile                  1329.00
#
#             MAX(transaction.amount)  COUNT(transaction)  \
# session_id
# 1                            141.66                  16
# 2                            135.25                  10
# 3                            147.73                  15
#
#             MODE(transaction.product_id)  YEAR(session_start)  \
# session_id
# 1                                      3                 2014
# 2                                      5                 2014
# 3                                      1                 2014
#
#             MONTH(session_start) customer.zip_code
# session_id
# 1                              1             13244
# 2                              1             60091
# 3                              1             60091

# %% [markdown]
# # ここから自作する ※未完

# %% [markdown]
# ## 関係ないカラムを除去しておく

# %%
transactions = df_transactions.drop(columns=['transaction_time']).copy()

transactions.head()
# Out:
#    transaction_id  session_id product_id  amount
# 0             298           1          5  127.64
# 1               2           1          2  109.48
# 2             308           1          3   95.06
# 3             116           1          4   78.92
# 4             371           1          3   31.54

# %%
sessions = df_sessions.copy()

sessions.head()
# Out:
#    session_id  customer_id   device       session_start
# 0           1            2  desktop 2014-01-01 00:00:00
# 1           2            5   mobile 2014-01-01 00:17:20
# 2           3            4   mobile 2014-01-01 00:28:10
# 3           4            1   mobile 2014-01-01 00:44:25
# 4           5            4   mobile 2014-01-01 01:11:30

# %% [markdown]
# ## Numericの部分だけのDFを作る

# %%
merged = pd.merge(sessions,
                  transactions,
                  on='session_id',
                  how='left')

merged.head()
# Out:
#    session_id  customer_id   device session_start  transaction_id product_id  \
# 0           1            2  desktop    2014-01-01             298          5
# 1           1            2  desktop    2014-01-01               2          2
# 2           1            2  desktop    2014-01-01             308          3
# 3           1            2  desktop    2014-01-01             116          4
# 4           1            2  desktop    2014-01-01             371          3
#
#    amount
# 0  127.64
# 1  109.48
# 2   95.06
# 3   78.92
# 4   31.54

# %%
agg_numeric = merged.groupby(['session_id', 'transaction_id'], as_index=False).agg({'amount': [sum, max]})

agg_numeric.head()
# Out:
#   session_id transaction_id  amount
#                                 sum     max
# 0          1              2  109.48  109.48
# 1          1             10   57.39   57.39
# 2          1             29   20.91   20.91
# 3          1            116   78.92   78.92
# 4          1            158  141.66  141.66

# %%
new_col_names = ['session_id']

for level_0 in agg_numeric.columns.levels[0]:
    if level_0 == 'session_id':
        continue

    for col_agg in agg_numeric.columns.levels[1][:-1]:
        new_col_name = f'{level_0.upper()}_{col_agg}'
        new_col_names.append(new_col_name)


agg_numeric.columns = new_col_names
# Out:
# ---------------------------------------
# ValueErrorTraceback (most recent call last)
# <ipython-input-67-fb3506b0d13e> in <module>
#      10
#      11
# ---> 12 agg_numeric.columns = new_col_names
#
# ~/src/github.com/mohira/kaggle-home-credit/.venv/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/src/github.com/mohira/kaggle-home-credit/.venv/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~/src/github.com/mohira/kaggle-home-credit/.venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 5 elements

# %%
agg_numeric.head()

# %% [markdown]
# ## Countの部分だけをつくる

# %%
expected.head()
# Out:
#             customer_id   device  SUM(transaction.amount)  \
# session_id
# 1                     2  desktop                  1229.01
# 2                     5   mobile                   746.96
# 3                     4   mobile                  1329.00
# 4                     1   mobile                  1613.93
# 5                     4   mobile                   777.02
#
#             MAX(transaction.amount)  COUNT(transaction)  \
# session_id
# 1                            141.66                  16
# 2                            135.25                  10
# 3                            147.73                  15
# 4                            129.00                  25
# 5                            139.20                  11
#
#             MODE(transaction.product_id)  YEAR(session_start)  \
# session_id
# 1                                      3                 2014
# 2                                      5                 2014
# 3                                      1                 2014
# 4                                      5                 2014
# 5                                      5                 2014
#
#             MONTH(session_start) customer.zip_code
# session_id
# 1                              1             13244
# 2                              1             60091
# 3                              1             60091
# 4                              1             60091
# 5                              1             60091

# %%
agg_count = merged.groupby('session_id', as_index=False).agg(
    {'transaction_id': [pd.Series.count]})

agg_count.columns = ['session_id', 'TRANSACTION_count']

agg_count.head()
# Out:
#    session_id  TRANSACTION_count
# 0           1                 16
# 1           2                 10
# 2           3                 15
# 3           4                 25
# 4           5                 11

# %% [markdown]
# ## ここまでをマージしてみる

# %%
tmp = pd.merge(agg_numeric, agg_count, on='session_id', how='left')

tmp.head()
# Out:
#    session_id  AMOUNT_sum  AMOUNT_max  TRANSACTION_count
# 0           1     1229.01      141.66                 16
# 1           2      746.96      135.25                 10
# 2           3     1329.00      147.73                 15
# 3           4     1613.93      129.00                 25
# 4           5      777.02      139.20                 11

# %%
# 比較
expected.head().reset_index()
# Out:
#    session_id  customer_id   device  SUM(transaction.amount)  \
# 0           1            2  desktop                  1229.01
# 1           2            5   mobile                   746.96
# 2           3            4   mobile                  1329.00
# 3           4            1   mobile                  1613.93
# 4           5            4   mobile                   777.02
#
#    MAX(transaction.amount)  COUNT(transaction)  MODE(transaction.product_id)  \
# 0                   141.66                  16                             3
# 1                   135.25                  10                             5
# 2                   147.73                  15                             1
# 3                   129.00                  25                             5
# 4                   139.20                  11                             5
#
#    YEAR(session_start)  MONTH(session_start) customer.zip_code
# 0                 2014                     1             13244
# 1                 2014                     1             60091
# 2                 2014                     1             60091
# 3                 2014                     1             60091
# 4                 2014                     1             60091

# %%
merged.groupby(by=['session_id', 'customer_id']).count()
# Out:
#                         device  session_start  transaction_id  product_id  \
# session_id customer_id
# 1          2                16             16              16          16
# 2          5                10             10              10          10
# 3          4                15             15              15          15
# 4          1                25             25              25          25
# 5          4                11             11              11          11
# 6          1                15             15              15          15
# 7          3                15             15              15          15
# 8          4                18             18              18          18
# 9          1                15             15              15          15
# 10         2                15             15              15          15
# 11         4                15             15              15          15
# 12         4                10             10              10          10
# 13         4                12             12              12          12
# 14         1                12             12              12          12
# 15         2                 8              8               8           8
# 16         2                10             10              10          10
# 17         2                13             13              13          13
# 18         1                12             12              12          12
# 19         3                17             17              17          17
# 20         5                15             15              15          15
# 21         4                18             18              18          18
# 22         4                10             10              10          10
# 23         3                11             11              11          11
# 24         5                14             14              14          14
# 25         3                16             16              16          16
# 26         1                16             16              16          16
# 27         1                15             15              15          15
# 28         5                18             18              18          18
# 29         1                16             16              16          16
# 30         5                14             14              14          14
# 31         2                18             18              18          18
# 32         5                 8              8               8           8
# 33         2                13             13              13          13
# 34         3                18             18              18          18
# 35         3                16             16              16          16
#
#                         amount
# session_id customer_id
# 1          2                16
# 2          5                10
# 3          4                15
# 4          1                25
# 5          4                11
# 6          1                15
# 7          3                15
# 8          4                18
# 9          1                15
# 10         2                15
# 11         4                15
# 12         4                10
# 13         4                12
# 14         1                12
# 15         2                 8
# 16         2                10
# 17         2                13
# 18         1                12
# 19         3                17
# 20         5                15
# 21         4                18
# 22         4                10
# 23         3                11
# 24         5                14
# 25         3                16
# 26         1                16
# 27         1                15
# 28         5                18
# 29         1                16
# 30         5                14
# 31         2                18
# 32         5                 8
# 33         2                13
# 34         3                18
# 35         3                16
